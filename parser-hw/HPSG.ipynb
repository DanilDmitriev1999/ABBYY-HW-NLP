# %%
# !git clone https://github.com/DanilDmitriev1999/ABBYY-HW-NLP
# Out:
# Cloning into 'ABBYY-HW-NLP'...
# remote: Enumerating objects: 253, done.
# remote: Counting objects: 100% (253/253), done.
# remote: Compressing objects: 100% (183/183), done.
# remote: Total 253 (delta 78), reused 231 (delta 62), pack-reused 0
# Receiving objects: 100% (253/253), 11.73 MiB | 17.18 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
cd /content/ABBYY-HW-NLP/parser-hw/HPSG
# Out:
# /content/ABBYY-HW-NLP/parser-hw/HPSG

# %%
# !pip install -q Cython==0.25.2
# !pip install -q torch==1.1.0
# !pip install -q numpy==1.17.4
# !pip install -q boto3
# Out:
#      |████████████████████████████████| 7.3MB 8.0MB/s
# ERROR: pycocotools 2.0.2 has requirement cython>=0.27.3, but you'll have cython 0.25.2 which is incompatible.
#      |████████████████████████████████| 676.9MB 26kB/s
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.1.0 which is incompatible.
#      |████████████████████████████████| 20.0MB 172kB/s
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.1.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
#      |████████████████████████████████| 133kB 7.6MB/s
#      |████████████████████████████████| 71kB 7.6MB/s
#      |████████████████████████████████| 7.0MB 10.8MB/s
#      |████████████████████████████████| 143kB 58.6MB/s
# ...

# %%
# !pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.1MB 7.6MB/s
# ...

# %%
cd EVALB/
# Out:
# /content/ABBYY-HW-NLP/parser-hw/HPSG/EVALB

# %%
# !make

# %%
cd /content/ABBYY-HW-NLP/parser-hw/HPSG
# Out:
# /content/ABBYY-HW-NLP/parser-hw/HPSG

# %%
# !sh run_bert.sh
# Out:
# Manual seed for pytorch: 503806481
# Hyperparameters:
# attention_dropout 0.2
# bert_do_lower_case True
# bert_model 'bert-large-uncased'
# bert_transliterate ''
# char_lstm_input_dropout 0.2
# clip_grad_norm 0.0
# const_lada 0.8
# d_biaffine 1024
# d_char_emb 64
# d_ff 2048
# d_kv 64
# d_label_hidden 250
# d_model 1024
# dataset 'ptb'
# elmo_dropout 0.5
# embedding_dropout 0.2
# embedding_path 'data/glove.gz'
# embedding_type 'random'
# learning_rate 5e-05
# learning_rate_warmup_steps 160
# max_len_dev 0
# max_len_train 0
# model_name 'joint_bert'
# morpho_emb_dropout 0.2
# num_heads 8
# num_layers 2
# pad_left False
# partitioned True
# punctuation ".``'':,"
# relu_dropout 0.2
# residual_dropout 0.2
# sentence_max_len 300
# step_decay True
# step_decay_factor 0.5
# step_decay_patience 5
# tag_emb_dropout 0.2
# timing_dropout 0.0
# use_bert True
# use_bert_only False
# use_cat False
# use_chars_lstm False
# use_elmo False
# use_tags False
# use_words False
# use_xlnet False
# ...

# %%
# !sh test.sh
# Out:
# Loading model from models/joint_bert_best_dev=95.39_devuas=96.51_devlas=94.34.pt...
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Reading dependency parsing data from data/test_dep.txt
# Loading test trees from data/test_con.txt...
# Loaded 2,416 test examples.
# Parsing test sentences...
# test-fscore (Recall=95.08, Precision=95.59, FScore=95.34) test-elapsed 0h01m00s
# best test W. Punct: ucorr: 54583, lcorr: 53592, total: 56684, uas: 96.29%, las: 94.55%, ucm: 64.90%, lcm: 49.30%
# ...
