# %%
# !git clone https://github.com/DanilDmitriev1999/ABBYY-HW-NLP
# Out:
# Cloning into 'ABBYY-HW-NLP'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (182/182), done.
# remote: Total 248 (delta 75), reused 225 (delta 58), pack-reused 0
# Receiving objects: 100% (248/248), 11.73 MiB | 19.28 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
cd /content/ABBYY-HW-NLP/parser-hw/self-attentive-parser-master
# Out:
# /content/ABBYY-HW-NLP/parser-hw/self-attentive-parser-master

# %%
# !pip install -q Cython==0.25.2
# !pip install -q torch==1.1.0
# !pip install -q numpy==1.17.4
# !pip install -q benepar[cpu]
# !pip install -q pytorch_pretrained_bert
# Out:
#      |████████████████████████████████| 7.3MB 8.3MB/s
# ERROR: pycocotools 2.0.2 has requirement cython>=0.27.3, but you'll have cython 0.25.2 which is incompatible.
#      |████████████████████████████████| 676.9MB 27kB/s
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.1.0 which is incompatible.
#      |████████████████████████████████| 20.0MB 173kB/s
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.1.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
#      |████████████████████████████████| 81kB 8.5MB/s
# ...
#      |████████████████████████████████| 133kB 23.6MB/s
#      |████████████████████████████████| 133kB 18.4MB/s
#      |████████████████████████████████| 7.0MB 32.6MB/s
# ...

# %%
cd EVALB/
# Out:
# /content/ABBYY-HW-NLP/parser-hw/self-attentive-parser-master/EVALB

# %%
# !make

# %%
cd /content/ABBYY-HW-NLP/parser-hw/self-attentive-parser-master
# Out:
# /content/ABBYY-HW-NLP/parser-hw/self-attentive-parser-master

# %%
# !python src/main.py train --use-bert --model-path-base models/en_bert --bert-model "bert-large-uncased" --epochs 4 --num-layers 2 --learning-rate 0.00005 --batch-size 32 --eval-batch-size 16 --subbatch-max-tokens 500
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 1 batch 20/1,245 processed 640 batch-loss 88.4856 grad-norm 164.2911 epoch-elapsed 0h00m24s total-elapsed 0h00m24s
# epoch 1 batch 21/1,245 processed 672 batch-loss 78.4890 grad-norm 164.5703 epoch-elapsed 0h00m25s total-elapsed 0h00m26s
# epoch 1 batch 22/1,245 processed 704 batch-loss 88.3139 grad-norm 128.1001 epoch-elapsed 0h00m27s total-elapsed 0h00m27s
# epoch 1 batch 23/1,245 processed 736 batch-loss 85.5869 grad-norm 140.5619 epoch-elapsed 0h00m28s total-elapsed 0h00m28s
# epoch 1 batch 24/1,245 processed 768 batch-loss 87.6851 grad-norm 120.7835 epoch-elapsed 0h00m29s total-elapsed 0h00m29s
# epoch 1 batch 25/1,245 processed 800 batch-loss 97.6280 grad-norm 146.2784 epoch-elapsed 0h00m30s total-elapsed 0h00m30s
# epoch 1 batch 26/1,245 processed 832 batch-loss 86.5966 grad-norm 2343.4322 epoch-elapsed 0h00m32s total-elapsed 0h00m32s
# ...
